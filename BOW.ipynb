# %% [markdown]
# <a href="https://colab.research.google.com/github/timmcoll03/simpleAnalysis/blob/main/BOW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.preprocessing.text import Tokenizer

docs = [
  'steak steak steak',
  'chicken steak cake steak cake cake',
  'cake cake cake cake chicken',
]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import io
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-12c79857-c25a-41de-852e-628277c42195" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-12c79857-c25a-41de-852e-628277c42195">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving trainData.csv to trainData.csv

# %%
train = pd.read_csv('trainData.csv',index_col=False)
train.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-902c91e04413> in <module>()
# ----> 1 train = pd.read_csv('mnist_test.csv',index_col=False)
#       2 train.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %%
## Step 1: Determine the Vocabulary
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train.review)
print(f'ListOfWords: {list(tokenizer.word_index.keys())}')
# Out:
# ListOfWords: ['the', 'and', 'a', 'of', 'to', 'is', 'br', 'in', 'it', 'i', 'this', 'that', 'was', 'as', 'for', 'with', 'movie', 'but', 'film', 'on', 'not', 'you', 'are', 'his', 'have', 'be', 'one', 'he', 'all', 'at', 'by', 'an', 'they', 'so', 'who', 'from', 'like', 'or', 'just', 'her', 'out', 'about', 'if', "it's", 'has', 'there', 'some', 'what', 'good', 'when', 'more', 'very', 'up', 'no', 'time', 'my', 'even', 'would', 'she', 'which', 'only', 'really', 'see', 'story', 'their', 'had', 'can', 'me', 'well', 'were', 'than', 'much', 'we', 'bad', 'been', 'get', 'do', 'great', 'other', 'will', 'also', 'into', 'people', 'because', 'how', 'first', 'him', 'most', "don't", 'made', 'then', 'its', 'them', 'make', 'way', 'too', 'movies', 'could', 'any', 'after', 'think', 'characters', 'watch', 'films', 'two', 'many', 'seen', 'character', 'being', 'never', 'plot', 'love', 'acting', 'life', 'did', 'best', 'where', 'know', 'show', 'little', 'over', 'off', 'ever', 'does', 'your', 'better', 'end', 'man
# ...

# %%
## Step 2: Count
display = tokenizer.texts_to_matrix(train.review, mode='count')
print(f'ListOfWords: {list(tokenizer.word_index.keys())}')

print(display)

# %%
df = pd.DataFrame(display)  
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-40f609745b00> in <module>()
# ----> 1 df = pd.DataFrame(display)
#       2 df.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     527         else:
#     528             if index is None or columns is None:
# --> 529                 raise ValueError("DataFrame constructor not properly called!")
#     530
#     531             if not dtype:
#
# ValueError: DataFrame constructor not properly called!

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(df)
print(kmeans.inertia_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-01a370b2bbe0> in <module>()
#       1 kmeans = KMeans(n_clusters=5)
# ----> 2 kmeans.fit(df)
#       3 print(kmeans.inertia_)
#
# NameError: name 'df' is not defined

# %%
rf = pd.DataFrame(kmeans.cluster_centers_)
rf.head
# Out:
# <bound method NDFrame.head of    0     1          2          3     ...      1056      1057      1058      1059
# 0   0.0  10.5   8.000000   5.500000  ...  0.000000  0.000000  0.000000  0.000000
# 1   0.0  36.0  18.000000  16.000000  ...  0.000000  0.000000  0.000000  0.000000
# 2   0.0   6.0   3.333333   2.777778  ...  0.111111  0.111111  0.111111  0.111111
# 3   0.0   8.0   4.000000   6.000000  ...  0.000000  0.000000  0.000000  0.000000
# 4   0.0  21.0   6.000000  10.000000  ...  0.000000  0.000000  0.000000  0.000000
#
# [5 rows x 1060 columns]>

# %%
cluster_map = pd.DataFrame()
cluster_map['data_index'] = df.index.values
cluster_map['cluster'] = kmeans.labels_
cluster_map.head()
# Out:
#    data_index  cluster
# 0           0        2
# 1           1        2
# 2           2        0
# 3           3        2
# 4           4        2
